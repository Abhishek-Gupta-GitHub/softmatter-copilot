# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://github.com/Abhishek-Gupta-GitHub/confocal_microscopy-copilot/blob/main/notebooks/main_demo.ipynb)

# %% [markdown]
# imports

# %%
from pathlib import Path

import numpy as np

from copilot.config import DEFAULT_META
from copilot.io_utils import (
    load_stack,
    save_stack,
    load_metadata,
    save_metadata,
    save_json,
)
from copilot.digital_twin import simulate_confocal_stack
from copilot.orchestrator import Orchestrator
from copilot.detection_tracking import DetectionTrackingWorker
from copilot.physics_analysis import PhysicsAnalyst
from copilot.chat_explainer import ChatExplainer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       1 from pathlib import Path
#       3 import numpy as np
# ----> 5 from copilot.config import DEFAULT_META
#       6 from copilot.io_utils import (
#       7     load_stack,
#       8     save_stack,
#    (...)
#      11     save_json,
#      12 )
#      13 from copilot.digital_twin import simulate_confocal_stack
#
# ModuleNotFoundError: No module named 'copilot'
